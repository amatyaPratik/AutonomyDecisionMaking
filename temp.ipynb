# %%
import numpy as np

# %%
q_table = np.load(".\q_table.npy")

# %%
q_table.shape
# Out:
# (11, 11, 4)

# %%
print(q_table[:,:,0])
# Out:
# [[-6.65623143e-01  0.00000000e+00  0.00000000e+00 -1.15608077e-02
#   -1.39018948e-01 -8.55919778e-02  4.92267470e-06  9.64187883e-04
#    1.18606152e-02  1.14788799e-02  1.02794062e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -5.11988717e-49
#   -4.86717640e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  1.14953187e-02  1.14960810e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -4.88290442e-02 -2.68601476e-02  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  9.75777580e-03]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -1.11390404e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -6.95297750e-01  0.00000000e+00]
# ...
